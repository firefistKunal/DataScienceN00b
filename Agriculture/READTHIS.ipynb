# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("apy.csv")

# %%
goa_data=data[data["State_Name"]=='Goa']

# %%
goa_data.head()
# Out:
#       State_Name District_Name  Crop_Year       Season                 Crop  \
# 56952        Goa     NORTH GOA       1997  Kharif                 Groundnut
# 56953        Goa     NORTH GOA       1997  Kharif       Other Kharif pulses
# 56954        Goa     NORTH GOA       1997  Rabi                   Groundnut
# 56955        Goa     NORTH GOA       1997  Rabi          Other  Rabi pulses
# 56956        Goa     NORTH GOA       1997  Whole Year                  Ragi
#
#          Area  Production
# 56952   310.0       376.0
# 56953   760.0        49.0
# 56954   829.0      1601.0
# 56955  7369.0      6241.0
# 56956  1675.0      1572.0

# %%
grouped_data=goa_data.groupby(['Crop_Year'])
grouped_data.head()
# Out:
#       State_Name District_Name  Crop_Year       Season                 Crop  \
# 56952        Goa     NORTH GOA       1997  Kharif                 Groundnut
# 56953        Goa     NORTH GOA       1997  Kharif       Other Kharif pulses
# 56954        Goa     NORTH GOA       1997  Rabi                   Groundnut
# 56955        Goa     NORTH GOA       1997  Rabi          Other  Rabi pulses
# 56956        Goa     NORTH GOA       1997  Whole Year                  Ragi
# 56957        Goa     NORTH GOA       2004  Kharif                 Groundnut
# 56958        Goa     NORTH GOA       2004  Kharif                      Ragi
# 56959        Goa     NORTH GOA       2004  Kharif                      Rice
# 56960        Goa     NORTH GOA       2004  Whole Year          Black pepper
# 56961        Goa     NORTH GOA       2004  Whole Year             Cashewnut
# 56964        Goa     NORTH GOA       2005  Kharif                 Groundnut
# ...

# %%
grouped_data['Area'].agg(np.sum)
# Out:
# Crop_Year
# 1997     35823.0
# 2004    137944.0
# 2005    137999.0
# 2006    138443.0
# 2007    138930.0
# 2008     64165.0
# 2009     58869.0
# 2010     58118.0
# 2011     61445.0
# 2012     59789.0
# 2013    156845.0
# 2014    157310.5
# Name: Area, dtype: float64
