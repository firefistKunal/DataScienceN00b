# %%
import pandas as pd
import numpy as np

# %%
raw = pd.read_csv("apy.csv")

# %%
cropdata=raw[raw['Crop']=='Rice']

# %%
ricearea=cropdata.groupby(['Crop_Year', [Season]])

# %%
ricearea

# %%
ricearea.head(10)
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 12      Andaman and Nicobar Islands      NICOBARS       2001  Kharif
# 18      Andaman and Nicobar Islands      NICOBARS       2002  Kharif
# 27      Andaman and Nicobar Islands      NICOBARS       2003  Kharif
# 36      Andaman and Nicobar Islands      NICOBARS       2004  Kharif
# ...                             ...           ...        ...          ...
# 148204                       Odisha     BALESHWAR       2015  Summer
# 148211                       Odisha     BALESHWAR       2015  Winter
# 148658                       Odisha       BARGARH       2015  Autumn
# 148663                       Odisha       BARGARH       2015  Summer
# 148672                       Odisha       BARGARH       2015  Winter
#
#         Crop       Area  Production
# 2       Rice     102.00      321.00
# 12      Rice      83.00      300.00
# ...

# %%
ricearea=cropdata.groupby(['Crop_Year', 'Season'])

# %%
ricearea.head(10)
# Out:
#                          State_Name   District_Name  Crop_Year       Season  \
# 2       Andaman and Nicobar Islands        NICOBARS       2000  Kharif
# 12      Andaman and Nicobar Islands        NICOBARS       2001  Kharif
# 18      Andaman and Nicobar Islands        NICOBARS       2002  Kharif
# 27      Andaman and Nicobar Islands        NICOBARS       2003  Kharif
# 36      Andaman and Nicobar Islands        NICOBARS       2004  Kharif
# ...                             ...             ...        ...          ...
# 154326                       Odisha      KENDRAPARA       2015  Summer
# 177125                       Sikkim   EAST DISTRICT       2015  Kharif
# 177297                       Sikkim  NORTH DISTRICT       2015  Kharif
# 177479                       Sikkim  SOUTH DISTRICT       2015  Kharif
# 177661                       Sikkim   WEST DISTRICT       2015  Kharif
#
#         Crop     Area  Production
# 2       Rice   102.00      321.00
# 12      Rice    83.00      300.00
# ...

# %%
ricearea=cropdata.groupby(['Crop_Year', 'Season'])['Area'].agg(np.sum).reset_index()

# %%
ricearea.head(10)
# Out:
#    Crop_Year       Season        Area
# 0       1997  Autumn        1589160.0
# 1       1997  Kharif       14208199.0
# 2       1997  Rabi          1178206.0
# 3       1997  Summer        1774289.0
# 4       1997  Whole Year    3001258.0
# 5       1997  Winter        8955355.0
# 6       1998  Autumn        2048299.0
# 7       1998  Kharif       20363660.0
# 8       1998  Rabi          1576346.0
# 9       1998  Summer        2470570.0

# %%
ricearea=cropdata.groupby(['Crop_Year', 'Season'])['Production'].agg(np.sum).reset_index()

# %%
ricearea.head(10)
# Out:
#    Crop_Year       Season  Production
# 0       1997  Autumn        1906333.0
# 1       1997  Kharif       32723519.0
# 2       1997  Rabi          3420352.0
# 3       1997  Summer        4782163.0
# 4       1997  Whole Year    8046603.0
# 5       1997  Winter       14969534.0
# 6       1998  Autumn        2198797.0
# 7       1998  Kharif       44949595.0
# 8       1998  Rabi          5024960.0
# 9       1998  Summer        7328354.0

# %%
import matplotlib.pyplot as plt
ricearea.plot(kind='line', subplots=True) 

plt.show()
